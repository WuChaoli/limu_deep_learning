# %%
# %matplotlib inline
import torch
from d2l import torch as d2l
import matplotlib.pyplot as plt

# %%
x = torch.arange(-8.0, 8.0, 0.1, requires_grad=True)
y = torch.relu(x)
x[0:5], y[0:5]
# Out:
# (tensor([-8.0000, -7.9000, -7.8000, -7.7000, -7.6000], grad_fn=<SliceBackward0>),
#  tensor([0., 0., 0., 0., 0.], grad_fn=<SliceBackward0>))

# %%
plt.plot(x.detach(), y.detach(), label="ReLU函数")
plt.xlabel("X轴")
plt.ylabel("Y轴")
plt.legend()
plt.show()

# %%
y.backward(torch.ones_like(x), retain_graph=True)
plt.plot(x.detach().numpy(), x.grad)
plt.show()

# %%
y = torch.sigmoid(x)
plt.plot(x.detach().numpy(), y.detach().numpy())
plt.show()

# %%
x.grad.data.zero_()
y.backward(torch.ones_like(x))
plt.plot(x.detach().numpy(), x.grad)
plt.show()
